# %%
import pandas as pd
df = pd.read_csv("middle_tn_schools.csv")

# %%
df.head()
# Out:
#                           name  school_rating   size  reduced_lunch  \
# 0  Allendale Elementary School            5.0  851.0           10.0
# 1          Anderson Elementary            2.0  412.0           71.0
# 2             Avoca Elementary            4.0  482.0           43.0
# 3                Bailey Middle            0.0  394.0           91.0
# 4          Barfield Elementary            4.0  948.0           26.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                 90.2                 95.8             15.7         Public
# 1                 32.8                 37.3             12.8         Public
# 2                 78.4                 83.6             16.6         Public
# 3                  1.6                  1.0             13.1  Public Magnet
# 4                 85.3                 89.2             14.8         Public
#
#    avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# ...

# %%
df.describe()
# Out:
#        school_rating         size  reduced_lunch  state_percentile_16  \
# count     347.000000   347.000000     347.000000           347.000000
# mean        2.968300   699.472622      50.279539            58.801729
# std         1.690377   400.598636      25.480236            32.540747
# min         0.000000    53.000000       2.000000             0.200000
# 25%         2.000000   420.500000      30.000000            30.950000
# 50%         3.000000   595.000000      51.000000            66.400000
# 75%         4.000000   851.000000      71.500000            88.000000
# max         5.000000  2314.000000      98.000000            99.800000
#
#        state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# count           341.000000       347.000000    341.000000    347.000000
# mean             58.249267        15.461671     57.004692     57.049856
# std              32.702630         5.725170     26.696450     27.968974
# ...

# %%
df.shape
# Out:
# (347, 15)

# %%
df['school_rating'][:5]
#df['school_rating'].head()
# Out:
# 0    5.0
# 1    2.0
# 2    4.0
# 3    0.0
# 4    4.0
# Name: school_rating, dtype: float64

# %%
df[['reduced_lunch', 'school_rating']].head()
# Out:
#    reduced_lunch  school_rating
# 0           10.0            5.0
# 1           71.0            2.0
# 2           43.0            4.0
# 3           91.0            0.0
# 4           26.0            4.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

coorelations = df[['reduced_lunch', 'school_rating']].corr()
#coorelations = df.corr()

sns.heatmap(data = coorelations, square=True, cmap="bwr")

plt.yticks(rotation=0)
plt.xticks(rotation=90)
# Out:
# (array([0.5, 1.5]), <a list of 2 Text xticklabel objects>)

# %%
# How many Schools , have got what kind of ratings ?
# Out:
#                name  size  reduced_lunch  state_percentile_16  \
# school_rating
# 0.0              43    43             43                   43
# 1.0              40    40             40                   40
# 2.0              44    44             44                   44
# 3.0              56    56             56                   56
# 4.0              86    86             86                   86
# 5.0              78    78             78                   78
#
#                state_percentile_15  stu_teach_ratio  school_type  \
# school_rating
# 0.0                             42               43           43
# 1.0                             38               40           40
# 2.0                             43               44           44
# 3.0                             56               56           56
# 4.0                             85               86           86
# 5.0                             77               78           78
#
# ...

# %% [markdown]
# ### Missing Values ?

# %%
## Is their any missing values in our dataset
# Out:
# name                   False
# school_rating          False
# size                   False
# reduced_lunch          False
# state_percentile_16    False
# state_percentile_15     True
# stu_teach_ratio        False
# school_type            False
# avg_score_15            True
# avg_score_16           False
# full_time_teachers     False
# percent_black          False
# percent_white          False
# percent_asian          False
# percent_hispanic       False
# dtype: bool

# %%
## How many missing values ?
# Out:
# name                   0
# school_rating          0
# size                   0
# reduced_lunch          0
# state_percentile_16    0
# state_percentile_15    6
# stu_teach_ratio        0
# school_type            0
# avg_score_15           6
# avg_score_16           0
# full_time_teachers     0
# percent_black          0
# percent_white          0
# percent_asian          0
# percent_hispanic       0
# dtype: int64

# %%
## Lets check for missing values in the SalaryGender dataset
df2 = pd.read_csv('SalaryGender.csv', delimiter=',')
df2.head()
# Out:
#    Salary  Gender  Age  PhD
# 0   140.0       1   47    1
# 1    30.0       0   65    1
# 2    35.1       0   56    0
# 3    30.0       1   23    0
# 4    80.0       0   53    1

# %%
## Is their any missing value in df2
# Out:
# Salary    False
# Gender    False
# Age       False
# PhD       False
# dtype: bool

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
## https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html

#imputer.fit(df[['state_percentile_15']])
#imputer.transform(df[['state_percentile_15']])
df['state_percentile_15'] = imputer.fit_transform(df[['state_percentile_15']])

df['state_percentile_15'].isna().sum()
# Out:
# 0
